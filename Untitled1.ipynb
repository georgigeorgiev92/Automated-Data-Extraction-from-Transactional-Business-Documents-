# %% [markdown]
# <a href="https://colab.research.google.com/github/georgigeorgiev92/Automated-Data-Extraction-from-Transactional-Business-Documents-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/georgigeorgiev92/CutieMLproject
# Out:
# Cloning into 'CutieMLproject'...
# remote: Enumerating objects: 9397, done.
# remote: Counting objects: 100% (9397/9397), done.
# remote: Compressing objects: 100% (6843/6843), done.
# remote: Total 9397 (delta 2210), reused 9290 (delta 2104), pack-reused 0
# Receiving objects: 100% (9397/9397), 70.69 MiB | 19.61 MiB/s, done.
# Resolving deltas: 100% (2210/2210), done.
# Checking out files: 100% (9811/9811), done.

# %%
# !ls CutieMLproject
# Out:
# bert_embedding.py	main_evaluate_json.py	 model_framework.py
# data			main.py			 others
# data_loader_json.py	main_train_json.py	 pip
# deprecated		model_cutie2_aspp.py	 pytesaract.py
# dict			model_cutie2_dilate.py	 README.md
# download_data.py	model_cutie2_fpn.py	 requirements.txt
# export_data.py		model_cutie2.py		 tesseractOCR.py
# helper.py		model_cutie_aspp.py	 test
# invoice_data		model_cutie_hr.py	 tokenization.py
# main_build_dict.py	model_cutie.py		 utils.py
# main_data_tokenizer.py	model_cutie_res_bert.py  venv

# %%
# !python3 /content/CutieMLproject/main_train_json.py
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Namespace(augment_strategy=1, batch_size=1, ckpt_file='CUTIE2_dilate_d20000c7(r80c80)_iter_1000.ckpt', ckpt_path='..\\CutieMLproject\\graph', ckpt_save_step=100, cols_segment=72, cols_target=64, cols_ulimit=80, data_augmentation_dropout=1, data_augmentation_extra=True, data_augmentation_extra_cols=16, data_augmentation_extra_rows=16, dict_path='/content/CutieMLproject/dict/40000_dictionary.npy', doc_path='/content/CutieMLproject/invoice_data', embedding_file='..\\graph\\bert\\multi_cased_L-12_H-768_A-12\\bert_model.ckpt', embedding_size=128, eps=1e-06, fill_bbox=False, ghm_bins=30, ghm_momentum=0, hard_negative_ratio=3, iterations=1000, learning_rate=0.0001, load_dict=True, load_dict_from_path='/content/CutieMLproject/dict/40000_dictionary.npy', log_disp_step=200, log_path='..\\CutieMLproject\\graph\\log', log_save_step=100, lr_decay_factor=0.1, lr_decay_step=13000, positional_mapping_strategy=1, restore_bertembedding_only=False, restore_ckpt=False, rows_segment=72, rows_target=64, rows_ulimit=80, save_prefix='SROIE', segment_grid=False, test_path='/content/CutieMLproject/test', test_step=400, text_case=True, tokenize=True, update_dict=False, use_cutie2=True, use_ghm=0, validation_step=200, weight_decay=0.0005)
#
#
# DATASET: 223 vocabularies, 8 target classes
# DATASET: 2 for training, 1 for validation
# DATASET: 2 for test from /content/CutieMLproject/test
#
# Training statistic:  [(23, 1), (14, 2), (13, 1)]
# 	 num:  2
# 	 rows statistic:  [(14, 1), (13, 1)]
# 	 cols statistic:  [(23, 1), (14, 1)]
#
# Validation statistic:  [(30, 1), (21, 1)]
# 	 num:  1
# 	 rows statistic:  [(21, 1)]
# 	 cols statistic:  [(30, 1)]
#
# Test statistic:  [(33, 1), (22, 1), (20, 1), (14, 1)]
# 	 num:  2
# 	 rows statistic:  [(20, 1), (14, 1)]
# 	 cols statistic:  [(33, 1), (22, 1)]
#
# DATASHAPE: data set with maximum grid table of (14,23), updated.
#
# Training grid AUGMENT size: (20,32) from (13,14)
# Training grid AUGMENT size: (16,62) from (14,23)
# Training grid AUGMENT size: (33,25) from (14,23)
# Training grid AUGMENT size: (35,31) from (13,14)
# Training grid AUGMENT size: (28,23) from (14,23)
# Training grid AUGMENT size: (13,31) from (13,14)
# Training grid AUGMENT size: (45,24) from (14,23)
# Training grid AUGMENT size: (15,18) from (13,14)
# Training grid AUGMENT size: (23,24) from (14,23)
# Training grid AUGMENT size: (18,22) from (13,14)
# Training grid AUGMENT size: (30,52) from (14,23)
# Training grid AUGMENT size: (15,32) from (13,14)
# Training grid AUGMENT size: (27,53) from (14,23)
# Training grid AUGMENT size: (30,16) from (13,14)
# Training grid AUGMENT size: (21,15) from (13,14)
# Training grid AUGMENT size: (26,30) from (14,23)
# Training grid AUGMENT size: (51,23) from (13,14)
# Training grid AUGMENT size: (21,38) from (14,23)
# Training grid AUGMENT size: (30,52) from (14,23)
# Training grid AUGMENT size: (16,32) from (13,14)
# Training grid AUGMENT size: (14,28) from (13,14)
# Training grid AUGMENT size: (15,47) from (14,23)
# Training grid AUGMENT size: (18,22) from (13,14)
# Training grid AUGMENT size: (16,26) from (14,23)
# Training grid AUGMENT size: (16,21) from (13,14)
# Training grid AUGMENT size: (24,40) from (14,23)
# Training grid AUGMENT size: (21,21) from (13,14)
# Training grid AUGMENT size: (30,25) from (14,23)
# Training grid AUGMENT size: (17,31) from (14,23)
# Training grid AUGMENT size: (13,28) from (13,14)
# Training grid AUGMENT size: (25,29) from (13,14)
# Training grid AUGMENT size: (20,32) from (14,23)
# Training grid AUGMENT size: (15,30) from (14,23)
# Training grid AUGMENT size: (24,46) from (13,14)
# Training grid AUGMENT size: (14,32) from (14,23)
# Training grid AUGMENT size: (27,37) from (13,14)
# Training grid AUGMENT size: (16,19) from (13,14)
# Training grid AUGMENT size: (30,28) from (14,23)
# Training grid AUGMENT size: (30,38) from (13,14)
# Training grid AUGMENT size: (17,52) from (14,23)
# Training grid AUGMENT size: (33,39) from (14,23)
# Training grid AUGMENT size: (22,26) from (13,14)
# Training grid AUGMENT size: (38,14) from (13,14)
# Training grid AUGMENT size: (34,33) from (14,23)
# Training grid AUGMENT size: (26,26) from (14,23)
# Training grid AUGMENT size: (23,28) from (13,14)
# Training grid AUGMENT size: (27,33) from (14,23)
# Training grid AUGMENT size: (21,16) from (13,14)
# Training grid AUGMENT size: (37,29) from (14,23)
# Training grid AUGMENT size: (36,18) from (13,14)
# Training grid AUGMENT size: (16,26) from (14,23)
# Training grid AUGMENT size: (18,28) from (13,14)
# Training grid AUGMENT size: (48,31) from (13,14)
# Training grid AUGMENT size: (20,25) from (14,23)
# Training grid AUGMENT size: (23,18) from (13,14)
# Training grid AUGMENT size: (15,45) from (14,23)
# Training grid AUGMENT size: (29,28) from (13,14)
# Training grid AUGMENT size: (26,33) from (14,23)
# Training grid AUGMENT size: (55,38) from (14,23)
# Training grid AUGMENT size: (25,20) from (13,14)
# Training grid AUGMENT size: (22,32) from (14,23)
# Training grid AUGMENT size: (38,21) from (13,14)
# Training grid AUGMENT size: (41,37) from (14,23)
# Training grid AUGMENT size: (15,19) from (13,14)
# Training grid AUGMENT size: (13,33) from (13,14)
# Training grid AUGMENT size: (19,34) from (14,23)
# Training grid AUGMENT size: (25,31) from (13,14)
# Training grid AUGMENT size: (17,29) from (14,23)
# Training grid AUGMENT size: (40,37) from (14,23)
# Training grid AUGMENT size: (31,16) from (13,14)
# Training grid AUGMENT size: (34,30) from (14,23)
# Training grid AUGMENT size: (29,22) from (13,14)
# Training grid AUGMENT size: (18,21) from (13,14)
# Training grid AUGMENT size: (39,47) from (14,23)
# Training grid AUGMENT size: (13,20) from (13,14)
# Training grid AUGMENT size: (27,30) from (14,23)
# Training grid AUGMENT size: (40,23) from (14,23)
# Training grid AUGMENT size: (36,29) from (13,14)
# Training grid AUGMENT size: (47,21) from (13,14)
# Training grid AUGMENT size: (23,48) from (14,23)
# Training grid AUGMENT size: (26,24) from (13,14)
# Training grid AUGMENT size: (24,48) from (14,23)
# Training grid AUGMENT size: (19,29) from (14,23)
# Training grid AUGMENT size: (24,24) from (13,14)
# Training grid AUGMENT size: (22,38) from (14,23)
# Training grid AUGMENT size: (21,31) from (13,14)
# Training grid AUGMENT size: (28,24) from (13,14)
# Training grid AUGMENT size: (17,36) from (14,23)
# Training grid AUGMENT size: (18,36) from (13,14)
# Training grid AUGMENT size: (23,35) from (14,23)
# Training grid AUGMENT size: (19,42) from (14,23)
# Training grid AUGMENT size: (17,34) from (13,14)
# Training grid AUGMENT size: (26,43) from (14,23)
# Training grid AUGMENT size: (32,20) from (13,14)
# Training grid AUGMENT size: (35,37) from (14,23)
# Training grid AUGMENT size: (27,31) from (13,14)
# Training grid AUGMENT size: (17,34) from (13,14)
# Training grid AUGMENT size: (19,35) from (14,23)
# Training grid AUGMENT size: (23,33) from (14,23)
# Training grid AUGMENT size: (16,32) from (13,14)
# Training grid AUGMENT size: (30,26) from (14,23)
# Training grid AUGMENT size: (28,42) from (13,14)
# Training grid AUGMENT size: (73,47) from (14,23)
# Training grid AUGMENT size: (32,20) from (13,14)
# Training grid AUGMENT size: (42,46) from (14,23)
# Training grid AUGMENT size: (27,33) from (13,14)
# Training grid AUGMENT size: (25,35) from (14,23)
# Training grid AUGMENT size: (27,40) from (13,14)
# Training grid AUGMENT size: (23,36) from (13,14)
# Training grid AUGMENT size: (34,24) from (14,23)
# Training grid AUGMENT size: (18,42) from (14,23)
# Training grid AUGMENT size: (41,18) from (13,14)
# Training grid AUGMENT size: (22,29) from (14,23)
# Training grid AUGMENT size: (27,15) from (13,14)
# Training grid AUGMENT size: (13,25) from (13,14)
# Training grid AUGMENT size: (16,24) from (14,23)
# Training grid AUGMENT size: (49,41) from (14,23)
# Training grid AUGMENT size: (19,53) from (13,14)
# Training grid AUGMENT size: (21,50) from (14,23)
# Training grid AUGMENT size: (30,37) from (13,14)
# Training grid AUGMENT size: (26,49) from (14,23)
# Training grid AUGMENT size: (43,25) from (13,14)
# Training grid AUGMENT size: (24,36) from (14,23)
# Training grid AUGMENT size: (20,26) from (13,14)
# Training grid AUGMENT size: (27,38) from (14,23)
# Training grid AUGMENT size: (22,15) from (13,14)
# Training grid AUGMENT size: (26,14) from (13,14)
# Training grid AUGMENT size: (17,28) from (14,23)
# Training grid AUGMENT size: (22,26) from (14,23)
# Training grid AUGMENT size: (32,23) from (13,14)
# Training grid AUGMENT size: (50,23) from (14,23)
# Training grid AUGMENT size: (17,14) from (13,14)
# Training grid AUGMENT size: (22,36) from (14,23)
# Training grid AUGMENT size: (20,43) from (13,14)
# Training grid AUGMENT size: (27,30) from (13,14)
# Training grid AUGMENT size: (24,33) from (14,23)
# Training grid AUGMENT size: (38,26) from (13,14)
# Training grid AUGMENT size: (20,24) from (14,23)
# Training grid AUGMENT size: (26,39) from (14,23)
# Training grid AUGMENT size: (30,23) from (13,14)
# Training grid AUGMENT size: (36,38) from (14,23)
# Training grid AUGMENT size: (24,17) from (13,14)
# Training grid AUGMENT size: (30,50) from (14,23)
# Training grid AUGMENT size: (21,28) from (13,14)
# Training grid AUGMENT size: (19,30) from (14,23)
# Training grid AUGMENT size: (18,20) from (13,14)
# Training grid AUGMENT size: (34,23) from (14,23)
# Training grid AUGMENT size: (27,14) from (13,14)
# Training grid AUGMENT size: (41,18) from (13,14)
# Training grid AUGMENT size: (33,29) from (14,23)
# Training grid AUGMENT size: (22,18) from (13,14)
# Training grid AUGMENT size: (16,26) from (14,23)
# Training grid AUGMENT size: (13,55) from (13,14)
# Training grid AUGMENT size: (28,27) from (14,23)
# Training grid AUGMENT size: (24,28) from (14,23)
# Training grid AUGMENT size: (30,16) from (13,14)
# Training grid AUGMENT size: (42,22) from (13,14)
# Training grid AUGMENT size: (22,30) from (14,23)
# Training grid AUGMENT size: (24,45) from (14,23)
# Training grid AUGMENT size: (13,17) from (13,14)
# Training grid AUGMENT size: (34,55) from (14,23)
# Training grid AUGMENT size: (26,31) from (13,14)
# Training grid AUGMENT size: (21,38) from (13,14)
# Training grid AUGMENT size: (14,37) from (14,23)
# Training grid AUGMENT size: (23,39) from (14,23)
# Training grid AUGMENT size: (36,16) from (13,14)
# Training grid AUGMENT size: (18,40) from (14,23)
# Training grid AUGMENT size: (16,17) from (13,14)
# Training grid AUGMENT size: (29,30) from (14,23)
# Training grid AUGMENT size: (39,47) from (13,14)
# Training grid AUGMENT size: (26,15) from (13,14)
# Training grid AUGMENT size: (30,31) from (14,23)
# Training grid AUGMENT size: (19,31) from (13,14)
# Training grid AUGMENT size: (33,30) from (14,23)
# Training grid AUGMENT size: (16,14) from (13,14)
# Training grid AUGMENT size: (19,44) from (14,23)
# Training grid AUGMENT size: (13,19) from (13,14)
# Training grid AUGMENT size: (18,26) from (14,23)
# Training grid AUGMENT size: (17,28) from (13,14)
# Training grid AUGMENT size: (17,31) from (14,23)
# Training grid AUGMENT size: (19,46) from (14,23)
# Training grid AUGMENT size: (16,16) from (13,14)
# Training grid AUGMENT size: (32,48) from (14,23)
# Training grid AUGMENT size: (17,36) from (13,14)
# Training grid AUGMENT size: (34,23) from (14,23)
# Training grid AUGMENT size: (48,27) from (13,14)
# Training grid AUGMENT size: (29,26) from (14,23)
# Training grid AUGMENT size: (17,23) from (13,14)
# Training grid AUGMENT size: (21,45) from (14,23)
# Training grid AUGMENT size: (26,23) from (13,14)
# Training grid AUGMENT size: (25,23) from (14,23)
# Training grid AUGMENT size: (14,36) from (13,14)
# Training grid AUGMENT size: (20,20) from (13,14)
# Training grid AUGMENT size: (46,35) from (14,23)
# Training grid AUGMENT size: (31,37) from (14,23)
# Training grid AUGMENT size: (18,36) from (13,14)
# Training grid AUGMENT size: (33,50) from (14,23)
# Training grid AUGMENT size: (17,18) from (13,14)
# Training grid AUGMENT size: (21,31) from (14,23)
# Training grid AUGMENT size: (19,26) from (13,14)
# Training grid AUGMENT size: (34,21) from (13,14)
# Training grid AUGMENT size: (21,31) from (14,23)
# Training grid AUGMENT size: (14,33) from (14,23)
# Training grid AUGMENT size: (23,39) from (13,14)
# Training grid AUGMENT size: (18,19) from (13,14)
# Training grid AUGMENT size: (18,45) from (14,23)
# Training grid AUGMENT size: (18,16) from (13,14)
# Training grid AUGMENT size: (18,55) from (14,23)
# Training grid AUGMENT size: (36,45) from (14,23)
# Training grid AUGMENT size: (19,15) from (13,14)
# Training grid AUGMENT size: (14,29) from (13,14)
# Training grid AUGMENT size: (20,27) from (14,23)
# Training grid AUGMENT size: (29,22) from (13,14)
# Training grid AUGMENT size: (17,39) from (14,23)
# Training grid AUGMENT size: (20,16) from (13,14)
# Training grid AUGMENT size: (31,25) from (14,23)
# Training grid AUGMENT size: (17,34) from (13,14)
# Training grid AUGMENT size: (20,30) from (14,23)
# Training grid AUGMENT size: (15,25) from (14,23)
# Training grid AUGMENT size: (18,17) from (13,14)
# Training grid AUGMENT size: (15,29) from (13,14)
# Training grid AUGMENT size: (15,24) from (14,23)
# Training grid AUGMENT size: (18,34) from (14,23)
# Training grid AUGMENT size: (44,38) from (13,14)
# Training grid AUGMENT size: (30,27) from (13,14)
# Training grid AUGMENT size: (15,30) from (14,23)
# Training grid AUGMENT size: (17,19) from (13,14)
# Training grid AUGMENT size: (17,51) from (14,23)
# Training grid AUGMENT size: (16,32) from (14,23)
# Training grid AUGMENT size: (18,16) from (13,14)
# Training grid AUGMENT size: (29,31) from (14,23)
# Training grid AUGMENT size: (22,30) from (13,14)
# Training grid AUGMENT size: (40,20) from (13,14)
# Training grid AUGMENT size: (16,25) from (14,23)
# Training grid AUGMENT size: (23,33) from (14,23)
# Training grid AUGMENT size: (34,19) from (13,14)
# Training grid AUGMENT size: (16,29) from (13,14)
# Training grid AUGMENT size: (18,49) from (14,23)
# Training grid AUGMENT size: (22,45) from (13,14)
# Training grid AUGMENT size: (20,41) from (14,23)
# Training grid AUGMENT size: (29,17) from (13,14)
# Training grid AUGMENT size: (16,39) from (14,23)
# Training grid AUGMENT size: (32,31) from (13,14)
# Training grid AUGMENT size: (25,29) from (14,23)
# Training grid AUGMENT size: (15,22) from (13,14)
# Training grid AUGMENT size: (15,39) from (14,23)
# Training grid AUGMENT size: (19,31) from (14,23)
# Training grid AUGMENT size: (33,23) from (13,14)
# Training grid AUGMENT size: (20,57) from (14,23)
# Training grid AUGMENT size: (25,15) from (13,14)
# Training grid AUGMENT size: (23,38) from (13,14)
# Training grid AUGMENT size: (30,47) from (14,23)
# Training grid AUGMENT size: (48,29) from (13,14)
# Training grid AUGMENT size: (14,28) from (14,23)
# Training grid AUGMENT size: (13,16) from (13,14)
# Training grid AUGMENT size: (25,29) from (14,23)
# Training grid AUGMENT size: (19,23) from (14,23)
# Training grid AUGMENT size: (18,27) from (13,14)
# Training grid AUGMENT size: (14,51) from (13,14)
# Training grid AUGMENT size: (30,49) from (14,23)
# Training grid AUGMENT size: (30,21) from (13,14)
# Training grid AUGMENT size: (36,46) from (14,23)
# Training grid AUGMENT size: (15,18) from (13,14)
# Training grid AUGMENT size: (23,26) from (14,23)
# Training grid AUGMENT size: (13,15) from (13,14)
# Training grid AUGMENT size: (24,34) from (14,23)
# Training grid AUGMENT size: (37,20) from (13,14)
# Training grid AUGMENT size: (29,27) from (14,23)
# Training grid AUGMENT size: (38,49) from (14,23)
# Training grid AUGMENT size: (22,26) from (13,14)
# Training grid AUGMENT size: (22,29) from (13,14)
# Training grid AUGMENT size: (33,60) from (14,23)
# Training grid AUGMENT size: (40,24) from (14,23)
# Training grid AUGMENT size: (49,22) from (13,14)
# Training grid AUGMENT size: (17,37) from (14,23)
# Training grid AUGMENT size: (19,19) from (13,14)
# Training grid AUGMENT size: (27,53) from (14,23)
# Training grid AUGMENT size: (23,39) from (13,14)
# Training grid AUGMENT size: (14,26) from (14,23)
# Training grid AUGMENT size: (34,41) from (13,14)
# Training grid AUGMENT size: (36,27) from (14,23)
# Training grid AUGMENT size: (23,37) from (13,14)
# Training grid AUGMENT size: (18,23) from (13,14)
# Training grid AUGMENT size: (27,44) from (14,23)
# Training grid AUGMENT size: (19,27) from (13,14)
# Training grid AUGMENT size: (17,32) from (14,23)
# Training grid AUGMENT size: (19,58) from (13,14)
# Training grid AUGMENT size: (29,28) from (14,23)
# Training grid AUGMENT size: (48,30) from (13,14)
# Training grid AUGMENT size: (24,29) from (14,23)
# Training grid AUGMENT size: (15,26) from (14,23)
# Training grid AUGMENT size: (26,39) from (13,14)
# Training grid AUGMENT size: (17,34) from (13,14)
# Training grid AUGMENT size: (35,30) from (14,23)
# Training grid AUGMENT size: (34,49) from (14,23)
# Training grid AUGMENT size: (14,37) from (13,14)
# Training grid AUGMENT size: (47,31) from (14,23)
# Training grid AUGMENT size: (22,23) from (13,14)
# Training grid AUGMENT size: (22,30) from (14,23)
# Training grid AUGMENT size: (14,43) from (13,14)
# Training grid AUGMENT size: (20,17) from (13,14)
# Training grid AUGMENT size: (15,38) from (14,23)
# Training grid AUGMENT size: (29,23) from (13,14)
# Training grid AUGMENT size: (23,52) from (14,23)
# Training grid AUGMENT size: (13,23) from (13,14)
# Training grid AUGMENT size: (18,40) from (14,23)
# Training grid AUGMENT size: (35,44) from (14,23)
# Training grid AUGMENT size: (23,38) from (13,14)
# Training grid AUGMENT size: (44,30) from (13,14)
# Training grid AUGMENT size: (22,44) from (14,23)
# Training grid AUGMENT size: (51,15) from (13,14)
# Training grid AUGMENT size: (35,27) from (14,23)
# Training grid AUGMENT size: (18,22) from (13,14)
# Training grid AUGMENT size: (22,29) from (14,23)
# Training grid AUGMENT size: (22,14) from (13,14)
# Training grid AUGMENT size: (14,34) from (14,23)
# Training grid AUGMENT size: (15,31) from (14,23)
# Training grid AUGMENT size: (27,19) from (13,14)
# Training grid AUGMENT size: (18,19) from (13,14)
# Training grid AUGMENT size: (21,28) from (14,23)
# Training grid AUGMENT size: (34,17) from (13,14)
# Training grid AUGMENT size: (27,23) from (14,23)
# Training grid AUGMENT size: (15,26) from (13,14)
# Training grid AUGMENT size: (25,30) from (14,23)
# Training grid AUGMENT size: (13,27) from (13,14)
# Training grid AUGMENT size: (23,31) from (14,23)
# Training grid AUGMENT size: (15,17) from (13,14)
# Training grid AUGMENT size: (25,23) from (14,23)
# Training grid AUGMENT size: (21,43) from (13,14)
# Training grid AUGMENT size: (16,38) from (14,23)
# Training grid AUGMENT size: (14,32) from (14,23)
# Training grid AUGMENT size: (23,20) from (13,14)
# Training grid AUGMENT size: (36,34) from (14,23)
# Training grid AUGMENT size: (20,17) from (13,14)
# Training grid AUGMENT size: (26,43) from (14,23)
# Training grid AUGMENT size: (28,49) from (13,14)
# Training grid AUGMENT size: (39,34) from (14,23)
# Training grid AUGMENT size: (25,28) from (13,14)
# Training grid AUGMENT size: (35,18) from (13,14)
# Training grid AUGMENT size: (27,43) from (14,23)
# Training grid AUGMENT size: (26,35) from (14,23)
# Training grid AUGMENT size: (23,16) from (13,14)
# Training grid AUGMENT size: (20,27) from (14,23)
# Training grid AUGMENT size: (33,39) from (13,14)
# Training grid AUGMENT size: (16,40) from (13,14)
# Training grid AUGMENT size: (15,27) from (14,23)
# Training grid AUGMENT size: (18,29) from (14,23)
# Training grid AUGMENT size: (17,21) from (13,14)
# Training grid AUGMENT size: (48,33) from (14,23)
# Training grid AUGMENT size: (16,23) from (13,14)
# Training grid AUGMENT size: (16,28) from (14,23)
# Training grid AUGMENT size: (32,16) from (13,14)
# Training grid AUGMENT size: (40,36) from (13,14)
# Training grid AUGMENT size: (32,47) from (14,23)
# Training grid AUGMENT size: (22,25) from (13,14)
# Training grid AUGMENT size: (20,43) from (14,23)
# Training grid AUGMENT size: (18,15) from (13,14)
# Training grid AUGMENT size: (31,24) from (14,23)
# Training grid AUGMENT size: (26,39) from (13,14)
# Training grid AUGMENT size: (38,48) from (14,23)
# Training grid AUGMENT size: (19,28) from (13,14)
# Training grid AUGMENT size: (34,46) from (14,23)
# Training grid AUGMENT size: (23,41) from (14,23)
# Training grid AUGMENT size: (17,49) from (13,14)
# Training grid AUGMENT size: (17,25) from (13,14)
# Training grid AUGMENT size: (15,28) from (14,23)
# Training grid AUGMENT size: (26,16) from (13,14)
# Training grid AUGMENT size: (37,24) from (14,23)
# Training grid AUGMENT size: (33,32) from (13,14)
# Training grid AUGMENT size: (28,25) from (14,23)
# Training grid AUGMENT size: (19,33) from (13,14)
# Training grid AUGMENT size: (32,30) from (14,23)
# Training grid AUGMENT size: (19,22) from (13,14)
# Training grid AUGMENT size: (16,26) from (14,23)
# Training grid AUGMENT size: (36,26) from (13,14)
# Training grid AUGMENT size: (24,34) from (14,23)
# Training grid AUGMENT size: (16,15) from (13,14)
# Training grid AUGMENT size: (17,32) from (14,23)
# Training grid AUGMENT size: (27,28) from (14,23)
# Training grid AUGMENT size: (16,18) from (13,14)
# Training grid AUGMENT size: (27,22) from (13,14)
# Training grid AUGMENT size: (22,59) from (14,23)
# Training grid AUGMENT size: (30,30) from (14,23)
# Training grid AUGMENT size: (24,23) from (13,14)
# Training grid AUGMENT size: (14,35) from (14,23)
# Training grid AUGMENT size: (26,19) from (13,14)
# Training grid AUGMENT size: (22,28) from (13,14)
# Training grid AUGMENT size: (19,28) from (14,23)
# Training grid AUGMENT size: (29,40) from (14,23)
# Training grid AUGMENT size: (16,50) from (13,14)
# Training grid AUGMENT size: (15,33) from (14,23)
# Training grid AUGMENT size: (16,14) from (13,14)
# Training grid AUGMENT size: (25,41) from (13,14)
# Training grid AUGMENT size: (25,39) from (14,23)
# Training grid AUGMENT size: (29,35) from (14,23)
# Training grid AUGMENT size: (28,32) from (13,14)
# Training grid AUGMENT size: (16,45) from (14,23)
# Training grid AUGMENT size: (26,20) from (13,14)
# Training grid AUGMENT size: (37,23) from (14,23)
# Training grid AUGMENT size: (18,15) from (13,14)
# Training grid AUGMENT size: (19,27) from (14,23)
# Training grid AUGMENT size: (25,31) from (13,14)
# Training grid AUGMENT size: (54,30) from (14,23)
# Training grid AUGMENT size: (28,32) from (13,14)
# Training grid AUGMENT size: (21,36) from (13,14)
# Training grid AUGMENT size: (52,27) from (14,23)
# Training grid AUGMENT size: (58,51) from (14,23)
# Training grid AUGMENT size: (20,14) from (13,14)
# Training grid AUGMENT size: (14,34) from (13,14)
# Training grid AUGMENT size: (28,28) from (14,23)
# Training grid AUGMENT size: (38,47) from (14,23)
# Training grid AUGMENT size: (25,44) from (13,14)
# Training grid AUGMENT size: (30,15) from (13,14)
# Training grid AUGMENT size: (21,30) from (14,23)
# Training grid AUGMENT size: (35,24) from (14,23)
# Training grid AUGMENT size: (14,18) from (13,14)
# Training grid AUGMENT size: (33,30) from (14,23)
# Training grid AUGMENT size: (20,45) from (13,14)
# Training grid AUGMENT size: (17,19) from (13,14)
# Training grid AUGMENT size: (20,25) from (14,23)
# Training grid AUGMENT size: (13,41) from (13,14)
# Training grid AUGMENT size: (35,37) from (14,23)
# Training grid AUGMENT size: (21,23) from (14,23)
# Training grid AUGMENT size: (20,17) from (13,14)
# Training grid AUGMENT size: (27,28) from (14,23)
# Training grid AUGMENT size: (22,30) from (13,14)
# Training grid AUGMENT size: (21,43) from (14,23)
# Training grid AUGMENT size: (27,26) from (13,14)
# Training grid AUGMENT size: (25,37) from (14,23)
# Training grid AUGMENT size: (25,24) from (13,14)
# Training grid AUGMENT size: (50,15) from (13,14)
# Training grid AUGMENT size: (28,25) from (14,23)
# Training grid AUGMENT size: (46,42) from (14,23)
# Training grid AUGMENT size: (25,50) from (13,14)
# Training grid AUGMENT size: (20,38) from (14,23)
# Training grid AUGMENT size: (14,33) from (13,14)
# Training grid AUGMENT size: (22,27) from (14,23)
# Training grid AUGMENT size: (26,14) from (13,14)
# Training grid AUGMENT size: (26,23) from (14,23)
# Training grid AUGMENT size: (28,29) from (13,14)
# Training grid AUGMENT size: (23,34) from (14,23)
# Training grid AUGMENT size: (17,21) from (13,14)
# Training grid AUGMENT size: (16,32) from (14,23)
# Training grid AUGMENT size: (32,19) from (13,14)
# Training grid AUGMENT size: (25,47) from (14,23)
# Training grid AUGMENT size: (29,23) from (13,14)
# Training grid AUGMENT size: (27,53) from (14,23)
# Training grid AUGMENT size: (24,29) from (13,14)
# Training grid AUGMENT size: (34,25) from (14,23)
# Training grid AUGMENT size: (24,31) from (13,14)
# Training grid AUGMENT size: (15,46) from (14,23)
# Training grid AUGMENT size: (28,21) from (13,14)
# Training grid AUGMENT size: (33,36) from (14,23)
# Training grid AUGMENT size: (18,26) from (13,14)
# Training grid AUGMENT size: (20,15) from (13,14)
# Training grid AUGMENT size: (29,29) from (14,23)
# Training grid AUGMENT size: (15,27) from (13,14)
# Training grid AUGMENT size: (15,40) from (14,23)
# Training grid AUGMENT size: (28,28) from (14,23)
# Training grid AUGMENT size: (44,27) from (13,14)
# Training grid AUGMENT size: (24,51) from (14,23)
# Training grid AUGMENT size: (17,32) from (13,14)
# Training grid AUGMENT size: (32,44) from (14,23)
# Training grid AUGMENT size: (16,14) from (13,14)
# Training grid AUGMENT size: (19,50) from (13,14)
# Training grid AUGMENT size: (37,38) from (14,23)
# Training grid AUGMENT size: (40,25) from (13,14)
# Training grid AUGMENT size: (23,28) from (14,23)
# Training grid AUGMENT size: (28,25) from (14,23)
# Training grid AUGMENT size: (17,24) from (13,14)
# Training grid AUGMENT size: (27,29) from (13,14)
# Training grid AUGMENT size: (34,27) from (14,23)
# Training grid AUGMENT size: (27,40) from (14,23)
# Training grid AUGMENT size: (18,14) from (13,14)
# Training grid AUGMENT size: (23,62) from (13,14)
# Training grid AUGMENT size: (20,32) from (14,23)
# Training grid AUGMENT size: (32,33) from (14,23)
# Training grid AUGMENT size: (21,29) from (13,14)
# Training grid AUGMENT size: (19,31) from (13,14)
# Training grid AUGMENT size: (21,25) from (14,23)
# Training grid AUGMENT size: (22,19) from (13,14)
# Training grid AUGMENT size: (20,34) from (14,23)
# Training grid AUGMENT size: (50,33) from (14,23)
# Training grid AUGMENT size: (29,37) from (13,14)
# Training grid AUGMENT size: (24,22) from (13,14)
# Training grid AUGMENT size: (20,34) from (14,23)
# Training grid AUGMENT size: (18,60) from (14,23)
# Training grid AUGMENT size: (33,26) from (13,14)
# Training grid AUGMENT size: (16,39) from (14,23)
# Training grid AUGMENT size: (16,15) from (13,14)
# Training grid AUGMENT size: (40,49) from (14,23)
# Training grid AUGMENT size: (16,39) from (13,14)
# Training grid AUGMENT size: (14,52) from (14,23)
# Training grid AUGMENT size: (25,29) from (13,14)
# Training grid AUGMENT size: (26,24) from (14,23)
# Training grid AUGMENT size: (31,28) from (13,14)
# Training grid AUGMENT size: (19,21) from (13,14)
# Training grid AUGMENT size: (34,30) from (14,23)
# Training grid AUGMENT size: (40,23) from (13,14)
# Training grid AUGMENT size: (14,58) from (14,23)
# Training grid AUGMENT size: (29,26) from (14,23)
# Training grid AUGMENT size: (22,23) from (13,14)
# Training grid AUGMENT size: (19,32) from (14,23)
# Training grid AUGMENT size: (30,30) from (13,14)
# Training grid AUGMENT size: (19,22) from (13,14)
# Training grid AUGMENT size: (39,35) from (14,23)
# Training grid AUGMENT size: (36,46) from (14,23)
# Training grid AUGMENT size: (15,28) from (13,14)
# Training grid AUGMENT size: (32,39) from (13,14)
# Training grid AUGMENT size: (46,68) from (14,23)
# Training grid AUGMENT size: (31,65) from (14,23)
# Training grid AUGMENT size: (24,41) from (13,14)
# Training grid AUGMENT size: (24,53) from (13,14)
# Training grid AUGMENT size: (19,34) from (14,23)
# Training grid AUGMENT size: (56,31) from (13,14)
# Training grid AUGMENT size: (39,35) from (14,23)
# Training grid AUGMENT size: (25,29) from (14,23)
# Training grid AUGMENT size: (45,30) from (13,14)
# Training grid AUGMENT size: (26,66) from (14,23)
# Training grid AUGMENT size: (14,34) from (13,14)
# Training grid AUGMENT size: (16,31) from (14,23)
# Training grid AUGMENT size: (36,40) from (13,14)
# Training grid AUGMENT size: (14,23) from (14,23)
# Training grid AUGMENT size: (33,14) from (13,14)
# Training grid AUGMENT size: (37,24) from (13,14)
# Training grid AUGMENT size: (42,32) from (14,23)
# Training grid AUGMENT size: (25,28) from (13,14)
# Training grid AUGMENT size: (16,24) from (14,23)
# Training grid AUGMENT size: (16,32) from (13,14)
# Training grid AUGMENT size: (38,38) from (14,23)
# Training grid AUGMENT size: (25,31) from (14,23)
# Training grid AUGMENT size: (24,21) from (13,14)
# Training grid AUGMENT size: (13,20) from (13,14)
# Training grid AUGMENT size: (20,27) from (14,23)
# Training grid AUGMENT size: (20,38) from (14,23)
# Training grid AUGMENT size: (27,23) from (13,14)
# Training grid AUGMENT size: (24,42) from (14,23)
# Training grid AUGMENT size: (13,21) from (13,14)
# Training grid AUGMENT size: (26,29) from (14,23)
# Training grid AUGMENT size: (51,28) from (13,14)
# Training grid AUGMENT size: (42,52) from (14,23)
# Training grid AUGMENT size: (20,16) from (13,14)
# Training grid AUGMENT size: (15,29) from (14,23)
# Training grid AUGMENT size: (23,18) from (13,14)
# Training grid AUGMENT size: (16,64) from (14,23)
# Training grid AUGMENT size: (29,15) from (13,14)
# Training grid AUGMENT size: (23,21) from (13,14)
# Training grid AUGMENT size: (18,24) from (14,23)
# Training grid AUGMENT size: (22,39) from (13,14)
# Training grid AUGMENT size: (26,39) from (14,23)
# Training grid AUGMENT size: (19,29) from (14,23)
# Training grid AUGMENT size: (28,18) from (13,14)
# Training grid AUGMENT size: (15,31) from (14,23)
# Training grid AUGMENT size: (20,21) from (13,14)
# Training grid AUGMENT size: (28,49) from (13,14)
# Training grid AUGMENT size: (16,36) from (14,23)
# Training grid AUGMENT size: (30,18) from (13,14)
# Training grid AUGMENT size: (37,23) from (14,23)
# Training grid AUGMENT size: (28,50) from (14,23)
# Training grid AUGMENT size: (23,23) from (13,14)
# Training grid AUGMENT size: (18,16) from (13,14)
# Training grid AUGMENT size: (15,37) from (14,23)
# Training grid AUGMENT size: (29,26) from (13,14)
# Training grid AUGMENT size: (16,48) from (14,23)
# Training grid AUGMENT size: (23,34) from (14,23)
# Training grid AUGMENT size: (17,20) from (13,14)
# Training grid AUGMENT size: (19,18) from (13,14)
# Training grid AUGMENT size: (29,23) from (14,23)
# Training grid AUGMENT size: (19,42) from (14,23)
# Training grid AUGMENT size: (42,17) from (13,14)
# Training grid AUGMENT size: (17,36) from (14,23)
# Training grid AUGMENT size: (42,36) from (13,14)
# Training grid AUGMENT size: (22,24) from (14,23)
# Training grid AUGMENT size: (13,18) from (13,14)
# Training grid AUGMENT size: (32,38) from (14,23)
# Training grid AUGMENT size: (13,27) from (13,14)
# Training grid AUGMENT size: (15,27) from (14,23)
# Training grid AUGMENT size: (18,33) from (13,14)
# Training grid AUGMENT size: (20,22) from (13,14)
# Training grid AUGMENT size: (21,23) from (14,23)
# Training grid AUGMENT size: (30,27) from (14,23)
# Training grid AUGMENT size: (41,18) from (13,14)
# Training grid AUGMENT size: (45,15) from (13,14)
# Training grid AUGMENT size: (28,38) from (14,23)
# Training grid AUGMENT size: (14,14) from (13,14)
# Training grid AUGMENT size: (21,44) from (14,23)
# Training grid AUGMENT size: (27,14) from (13,14)
# Training grid AUGMENT size: (32,46) from (14,23)
# Training grid AUGMENT size: (20,18) from (13,14)
# Training grid AUGMENT size: (22,28) from (14,23)
# Training grid AUGMENT size: (17,41) from (14,23)
# Training grid AUGMENT size: (15,15) from (13,14)
# Training grid AUGMENT size: (14,24) from (14,23)
# Training grid AUGMENT size: (34,17) from (13,14)
# Training grid AUGMENT size: (27,25) from (14,23)
# Training grid AUGMENT size: (22,40) from (13,14)
# Training grid AUGMENT size: (28,28) from (13,14)
# Training grid AUGMENT size: (14,30) from (14,23)
# Training grid AUGMENT size: (24,36) from (14,23)
# Training grid AUGMENT size: (29,21) from (13,14)
# Training grid AUGMENT size: (17,27) from (13,14)
# Training grid AUGMENT size: (39,26) from (14,23)
# Training grid AUGMENT size: (18,39) from (14,23)
# Training grid AUGMENT size: (28,16) from (13,14)
# Training grid AUGMENT size: (32,19) from (13,14)
# Training grid AUGMENT size: (22,46) from (14,23)
# Training grid AUGMENT size: (23,21) from (13,14)
# Training grid AUGMENT size: (29,39) from (14,23)
# Training grid AUGMENT size: (24,54) from (13,14)
# Training grid AUGMENT size: (39,36) from (14,23)
# Training grid AUGMENT size: (28,30) from (14,23)
# Training grid AUGMENT size: (27,18) from (13,14)
# Training grid AUGMENT size: (44,20) from (13,14)
# Training grid AUGMENT size: (17,25) from (14,23)
# Training grid AUGMENT size: (22,26) from (14,23)
# Training grid AUGMENT size: (33,24) from (13,14)
# Training grid AUGMENT size: (34,20) from (13,14)
# Training grid AUGMENT size: (34,48) from (14,23)
# Training grid AUGMENT size: (20,35) from (14,23)
# Training grid AUGMENT size: (38,14) from (13,14)
# Training grid AUGMENT size: (21,27) from (13,14)
# Training grid AUGMENT size: (39,25) from (14,23)
# Training grid AUGMENT size: (28,54) from (14,23)
# Training grid AUGMENT size: (40,19) from (13,14)
# Training grid AUGMENT size: (32,42) from (14,23)
# Training grid AUGMENT size: (22,30) from (13,14)
# Training grid AUGMENT size: (30,17) from (13,14)
# Training grid AUGMENT size: (18,24) from (14,23)
# Training grid AUGMENT size: (21,36) from (14,23)
# Training grid AUGMENT size: (24,24) from (13,14)
# Training grid AUGMENT size: (26,26) from (14,23)
# Training grid AUGMENT size: (24,42) from (13,14)
# Training grid AUGMENT size: (14,34) from (13,14)
# Training grid AUGMENT size: (26,36) from (14,23)
# Training grid AUGMENT size: (22,28) from (14,23)
# Training grid AUGMENT size: (26,17) from (13,14)
# Training grid AUGMENT size: (16,15) from (13,14)
# Training grid AUGMENT size: (20,23) from (14,23)
# Training grid AUGMENT size: (25,28) from (13,14)
# Training grid AUGMENT size: (24,27) from (14,23)
# Training grid AUGMENT size: (26,25) from (14,23)
# Training grid AUGMENT size: (28,40) from (13,14)
# Training grid AUGMENT size: (17,34) from (13,14)
# Training grid AUGMENT size: (63,49) from (14,23)
# Training grid AUGMENT size: (20,28) from (14,23)
# Training grid AUGMENT size: (33,25) from (13,14)
# Training grid AUGMENT size: (30,31) from (13,14)
# Training grid AUGMENT size: (47,41) from (14,23)
# Training grid AUGMENT size: (26,22) from (13,14)
# Training grid AUGMENT size: (18,48) from (14,23)
# Training grid AUGMENT size: (42,18) from (13,14)
# Training grid AUGMENT size: (18,28) from (14,23)
# Training grid AUGMENT size: (14,17) from (13,14)
# Training grid AUGMENT size: (30,28) from (14,23)
# Training grid AUGMENT size: (26,25) from (13,14)
# Training grid AUGMENT size: (20,26) from (14,23)
# Training grid AUGMENT size: (31,65) from (14,23)
# Training grid AUGMENT size: (21,29) from (13,14)
# Training grid AUGMENT size: (49,36) from (13,14)
# Training grid AUGMENT size: (25,40) from (14,23)
# Training grid AUGMENT size: (20,42) from (13,14)
# Training grid AUGMENT size: (16,33) from (14,23)
# Training grid AUGMENT size: (31,33) from (13,14)
# Training grid AUGMENT size: (15,37) from (14,23)
# Training grid AUGMENT size: (16,42) from (13,14)
# Training grid AUGMENT size: (31,34) from (14,23)
# Training grid AUGMENT size: (43,38) from (14,23)
# Training grid AUGMENT size: (21,16) from (13,14)
# Training grid AUGMENT size: (15,24) from (14,23)
# Training grid AUGMENT size: (21,32) from (13,14)
# Training grid AUGMENT size: (43,23) from (14,23)
# Training grid AUGMENT size: (50,24) from (13,14)
# Training grid AUGMENT size: (33,31) from (13,14)
# Training grid AUGMENT size: (20,29) from (14,23)
# Training grid AUGMENT size: (21,40) from (13,14)
# Training grid AUGMENT size: (23,27) from (14,23)
# Training grid AUGMENT size: (30,14) from (13,14)
# Training grid AUGMENT size: (35,26) from (14,23)
# Training grid AUGMENT size: (40,18) from (13,14)
# Training grid AUGMENT size: (22,28) from (14,23)
# Training grid AUGMENT size: (19,56) from (14,23)
# Training grid AUGMENT size: (31,23) from (13,14)
# Training grid AUGMENT size: (20,30) from (13,14)
# Training grid AUGMENT size: (29,35) from (14,23)
# Training grid AUGMENT size: (32,32) from (13,14)
# Training grid AUGMENT size: (45,25) from (14,23)
# Training grid AUGMENT size: (22,26) from (13,14)
# Training grid AUGMENT size: (57,47) from (14,23)
# Training grid AUGMENT size: (21,37) from (14,23)
# Training grid AUGMENT size: (30,21) from (13,14)
# Training grid AUGMENT size: (41,36) from (14,23)
# Training grid AUGMENT size: (16,27) from (13,14)
# Training grid AUGMENT size: (18,21) from (13,14)
# Training grid AUGMENT size: (31,47) from (14,23)
# Training grid AUGMENT size: (32,45) from (14,23)
# Training grid AUGMENT size: (22,19) from (13,14)
# Training grid AUGMENT size: (14,43) from (14,23)
# Training grid AUGMENT size: (16,38) from (13,14)
# Training grid AUGMENT size: (28,33) from (14,23)
# Training grid AUGMENT size: (46,17) from (13,14)
# Training grid AUGMENT size: (29,46) from (14,23)
# Training grid AUGMENT size: (38,20) from (13,14)
# Training grid AUGMENT size: (21,58) from (14,23)
# Training grid AUGMENT size: (19,15) from (13,14)
# Training grid AUGMENT size: (41,33) from (13,14)
# Training grid AUGMENT size: (17,30) from (14,23)
# Training grid AUGMENT size: (45,22) from (13,14)
# Training grid AUGMENT size: (21,32) from (14,23)
# Training grid AUGMENT size: (25,14) from (13,14)
# Training grid AUGMENT size: (29,34) from (14,23)
# Training grid AUGMENT size: (19,27) from (13,14)
# Training grid AUGMENT size: (44,41) from (14,23)
# Training grid AUGMENT size: (22,31) from (14,23)
# Training grid AUGMENT size: (24,45) from (13,14)
# Training grid AUGMENT size: (30,38) from (14,23)
# Training grid AUGMENT size: (35,14) from (13,14)
# Training grid AUGMENT size: (16,38) from (13,14)
# Training grid AUGMENT size: (23,31) from (14,23)
# Training grid AUGMENT size: (13,23) from (13,14)
# Training grid AUGMENT size: (30,41) from (14,23)
# Training grid AUGMENT size: (15,29) from (14,23)
# Training grid AUGMENT size: (16,20) from (13,14)
# Training grid AUGMENT size: (42,33) from (13,14)
# Training grid AUGMENT size: (20,47) from (14,23)
# Training grid AUGMENT size: (20,29) from (13,14)
# Training grid AUGMENT size: (33,25) from (14,23)
# Training grid AUGMENT size: (15,36) from (14,23)
# Training grid AUGMENT size: (25,23) from (13,14)
# Training grid AUGMENT size: (17,29) from (14,23)
# Training grid AUGMENT size: (31,27) from (13,14)
# Training grid AUGMENT size: (41,31) from (14,23)
# Training grid AUGMENT size: (19,28) from (13,14)
# Training grid AUGMENT size: (28,33) from (14,23)
# Training grid AUGMENT size: (20,23) from (13,14)
# Training grid AUGMENT size: (26,27) from (13,14)
# Training grid AUGMENT size: (17,49) from (14,23)
# Training grid AUGMENT size: (14,31) from (14,23)
# Training grid AUGMENT size: (40,18) from (13,14)
# Training grid AUGMENT size: (36,34) from (14,23)
# Training grid AUGMENT size: (17,48) from (13,14)
# Training grid AUGMENT size: (30,51) from (13,14)
# Training grid AUGMENT size: (20,45) from (14,23)
# Training grid AUGMENT size: (15,54) from (14,23)
# Training grid AUGMENT size: (30,19) from (13,14)
# Training grid AUGMENT size: (38,39) from (14,23)
# Training grid AUGMENT size: (46,14) from (13,14)
# Training grid AUGMENT size: (33,30) from (14,23)
# Training grid AUGMENT size: (24,16) from (13,14)
# Training grid AUGMENT size: (36,26) from (14,23)
# Training grid AUGMENT size: (22,20) from (13,14)
# Training grid AUGMENT size: (19,48) from (14,23)
# Training grid AUGMENT size: (25,27) from (13,14)
# Training grid AUGMENT size: (18,41) from (14,23)
# Training grid AUGMENT size: (17,20) from (13,14)
# Training grid AUGMENT size: (32,15) from (13,14)
# Training grid AUGMENT size: (46,29) from (14,23)
# Training grid AUGMENT size: (27,14) from (13,14)
# Training grid AUGMENT size: (17,46) from (14,23)
# Training grid AUGMENT size: (35,26) from (14,23)
# Training grid AUGMENT size: (22,44) from (13,14)
# Training grid AUGMENT size: (24,46) from (14,23)
# Training grid AUGMENT size: (35,25) from (13,14)
# Training grid AUGMENT size: (27,25) from (13,14)
# Training grid AUGMENT size: (16,36) from (14,23)
# Training grid AUGMENT size: (24,45) from (14,23)
# Training grid AUGMENT size: (27,19) from (13,14)
# Training grid AUGMENT size: (14,58) from (14,23)
# Training grid AUGMENT size: (24,29) from (13,14)
# Training grid AUGMENT size: (14,19) from (13,14)
# Training grid AUGMENT size: (27,23) from (14,23)
# Training grid AUGMENT size: (16,45) from (14,23)
# Training grid AUGMENT size: (17,38) from (13,14)
# Training grid AUGMENT size: (37,20) from (13,14)
# Training grid AUGMENT size: (31,23) from (14,23)
# Training grid AUGMENT size: (19,50) from (14,23)
# Training grid AUGMENT size: (39,29) from (13,14)
# Training grid AUGMENT size: (34,32) from (14,23)
# Training grid AUGMENT size: (27,22) from (13,14)
# Training grid AUGMENT size: (17,38) from (14,23)
# Training grid AUGMENT size: (14,53) from (13,14)
# Training grid AUGMENT size: (15,26) from (14,23)
# Training grid AUGMENT size: (22,42) from (13,14)
# Training grid AUGMENT size: (24,21) from (13,14)
# Training grid AUGMENT size: (21,25) from (14,23)
# Training grid AUGMENT size: (31,60) from (14,23)
# Training grid AUGMENT size: (54,20) from (13,14)
# Training grid AUGMENT size: (20,44) from (14,23)
# Training grid AUGMENT size: (22,22) from (13,14)
# Training grid AUGMENT size: (18,18) from (13,14)
# Training grid AUGMENT size: (31,39) from (14,23)
# Training grid AUGMENT size: (17,15) from (13,14)
# Training grid AUGMENT size: (21,27) from (14,23)
# Training grid AUGMENT size: (25,35) from (13,14)
# Training grid AUGMENT size: (27,50) from (14,23)
# Training grid AUGMENT size: (31,33) from (14,23)
# Training grid AUGMENT size: (15,49) from (13,14)
# Training grid AUGMENT size: (42,41) from (13,14)
# Training grid AUGMENT size: (14,31) from (14,23)
# Training grid AUGMENT size: (20,27) from (13,14)
# Training grid AUGMENT size: (17,24) from (14,23)
# Training grid AUGMENT size: (26,40) from (14,23)
# Training grid AUGMENT size: (28,23) from (13,14)
# Training grid AUGMENT size: (32,52) from (14,23)
# Training grid AUGMENT size: (34,23) from (13,14)
# Training grid AUGMENT size: (20,16) from (13,14)
# Training grid AUGMENT size: (21,34) from (14,23)
# Training grid AUGMENT size: (26,15) from (13,14)
# Training grid AUGMENT size: (27,24) from (14,23)
# Training grid AUGMENT size: (29,26) from (13,14)
# Training grid AUGMENT size: (24,38) from (14,23)
# Training grid AUGMENT size: (20,20) from (13,14)
# Training grid AUGMENT size: (48,42) from (14,23)
# Training grid AUGMENT size: (18,26) from (13,14)
# Training grid AUGMENT size: (21,54) from (14,23)
# Training grid AUGMENT size: (27,43) from (14,23)
# Training grid AUGMENT size: (16,17) from (13,14)
# Training grid AUGMENT size: (19,30) from (14,23)
# Training grid AUGMENT size: (40,59) from (13,14)
# Training grid AUGMENT size: (14,36) from (13,14)
# Training grid AUGMENT size: (24,43) from (14,23)
# Training grid AUGMENT size: (15,28) from (14,23)
# Training grid AUGMENT size: (18,37) from (13,14)
# Training grid AUGMENT size: (39,22) from (13,14)
# Training grid AUGMENT size: (23,43) from (14,23)
# Training grid AUGMENT size: (19,18) from (13,14)
# Training grid AUGMENT size: (18,33) from (14,23)
# Training grid AUGMENT size: (22,23) from (13,14)
# Training grid AUGMENT size: (21,35) from (14,23)
# Training grid AUGMENT size: (22,22) from (13,14)
# Training grid AUGMENT size: (24,24) from (14,23)
# Training grid AUGMENT size: (21,37) from (14,23)
# Training grid AUGMENT size: (35,51) from (13,14)
# Training grid AUGMENT size: (13,14) from (13,14)
# Training grid AUGMENT size: (22,35) from (14,23)
# Training grid AUGMENT size: (21,27) from (13,14)
# Training grid AUGMENT size: (34,49) from (14,23)
# Training grid AUGMENT size: (26,26) from (13,14)
# Training grid AUGMENT size: (29,37) from (14,23)
# Training grid AUGMENT size: (18,34) from (13,14)
# Training grid AUGMENT size: (25,27) from (14,23)
# Training grid AUGMENT size: (29,23) from (14,23)
# Training grid AUGMENT size: (21,19) from (13,14)
# Training grid AUGMENT size: (25,38) from (13,14)
# Training grid AUGMENT size: (31,40) from (14,23)
# Training grid AUGMENT size: (14,37) from (14,23)
# Training grid AUGMENT size: (18,32) from (13,14)
# Training grid AUGMENT size: (25,49) from (14,23)
# Training grid AUGMENT size: (38,32) from (13,14)
# Training grid AUGMENT size: (15,28) from (13,14)
# Training grid AUGMENT size: (23,28) from (14,23)
# Training grid AUGMENT size: (25,29) from (14,23)
# Training grid AUGMENT size: (21,37) from (13,14)
# Training grid AUGMENT size: (37,31) from (13,14)
# Training grid AUGMENT size: (18,48) from (14,23)
# Training grid AUGMENT size: (27,25) from (14,23)
# Training grid AUGMENT size: (20,28) from (13,14)
# Training grid AUGMENT size: (17,46) from (14,23)
# Training grid AUGMENT size: (16,60) from (13,14)
# Training grid AUGMENT size: (17,56) from (14,23)
# Training grid AUGMENT size: (36,54) from (13,14)
# Training grid AUGMENT size: (35,30) from (14,23)
# Training grid AUGMENT size: (49,38) from (13,14)
# Training grid AUGMENT size: (25,27) from (14,23)
# Training grid AUGMENT size: (16,32) from (13,14)
# Training grid AUGMENT size: (25,59) from (14,23)
# Training grid AUGMENT size: (21,15) from (13,14)
# Training grid AUGMENT size: (20,27) from (13,14)
# Training grid AUGMENT size: (24,40) from (14,23)
# Training grid AUGMENT size: (21,25) from (14,23)
# ...
# Training grid AUGMENT size: (13,29) from (13,14)
# Training grid AUGMENT size: (18,43) from (14,23)
# Training grid AUGMENT size: (35,32) from (13,14)
# Training grid AUGMENT size: (26,50) from (14,23)
# Training grid AUGMENT size: (22,47) from (13,14)
# Training grid AUGMENT size: (24,45) from (14,23)
# Training grid AUGMENT size: (15,19) from (13,14)
# Training grid AUGMENT size: (29,35) from (13,14)
# Training grid AUGMENT size: (36,33) from (14,23)
# Training grid AUGMENT size: (15,31) from (13,14)
# Training grid AUGMENT size: (26,33) from (14,23)
# Training grid AUGMENT size: (58,36) from (14,23)
# Training grid AUGMENT size: (33,20) from (13,14)
# Training grid AUGMENT size: (22,45) from (14,23)
# Training grid AUGMENT size: (18,19) from (13,14)
# Training grid AUGMENT size: (24,36) from (13,14)
# Training grid AUGMENT size: (18,36) from (14,23)
# Training grid AUGMENT size: (26,27) from (13,14)
# Training grid AUGMENT size: (22,23) from (14,23)
# Training grid AUGMENT size: (17,26) from (13,14)
# Training grid AUGMENT size: (24,41) from (14,23)
# Training grid AUGMENT size: (31,25) from (13,14)
# Training grid AUGMENT size: (26,37) from (14,23)
# Training grid AUGMENT size: (29,24) from (13,14)
# Training grid AUGMENT size: (23,33) from (14,23)
# Training grid AUGMENT size: (14,19) from (13,14)
# Training grid AUGMENT size: (28,41) from (14,23)
# Training grid AUGMENT size: (18,25) from (14,23)
# Training grid AUGMENT size: (21,17) from (13,14)
# Training grid AUGMENT size: (49,46) from (14,23)
# Training grid AUGMENT size: (19,27) from (13,14)
# Training grid AUGMENT size: (20,40) from (14,23)
# Training grid AUGMENT size: (15,29) from (13,14)
# Training grid AUGMENT size: (15,23) from (14,23)
# Training grid AUGMENT size: (22,17) from (13,14)
# Training grid AUGMENT size: (42,23) from (14,23)
# Training grid AUGMENT size: (26,36) from (13,14)
# Training grid AUGMENT size: (15,31) from (14,23)
# Training grid AUGMENT size: (20,42) from (13,14)
# Training grid AUGMENT size: (18,31) from (13,14)
# Training grid AUGMENT size: (29,51) from (14,23)
# Training grid AUGMENT size: (17,27) from (13,14)
# Training grid AUGMENT size: (37,38) from (14,23)
# Training grid AUGMENT size: (47,26) from (13,14)
# Training grid AUGMENT size: (23,28) from (14,23)
# Training grid AUGMENT size: (26,35) from (14,23)
# Training grid AUGMENT size: (43,31) from (13,14)
# Training grid AUGMENT size: (46,44) from (14,23)
# Training grid AUGMENT size: (26,24) from (13,14)
# Training grid AUGMENT size: (38,30) from (14,23)
# Training grid AUGMENT size: (16,30) from (13,14)
# Training grid AUGMENT size: (21,50) from (14,23)
# Training grid AUGMENT size: (28,39) from (13,14)
# Training grid AUGMENT size: (16,42) from (14,23)
# Training grid AUGMENT size: (13,22) from (13,14)
# Training grid AUGMENT size: (48,27) from (14,23)
# Training grid AUGMENT size: (35,19) from (13,14)
# Training grid AUGMENT size: (32,28) from (14,23)
# Training grid AUGMENT size: (42,56) from (13,14)
# Training grid AUGMENT size: (34,45) from (13,14)
# Training grid AUGMENT size: (29,35) from (14,23)
# Training grid AUGMENT size: (30,43) from (13,14)
# Training grid AUGMENT size: (52,31) from (14,23)
# Training grid AUGMENT size: (21,27) from (13,14)
# Training grid AUGMENT size: (32,62) from (14,23)
# Training grid AUGMENT size: (24,23) from (13,14)
# Training grid AUGMENT size: (21,55) from (14,23)
# Training grid AUGMENT size: (34,39) from (14,23)
# Training grid AUGMENT size: (19,33) from (13,14)
# Training grid AUGMENT size: (30,29) from (13,14)
# Training grid AUGMENT size: (16,41) from (14,23)
# Training grid AUGMENT size: (19,19) from (13,14)
# Training grid AUGMENT size: (17,25) from (14,23)
# Training grid AUGMENT size: (42,23) from (14,23)
# Training grid AUGMENT size: (18,21) from (13,14)
# Training grid AUGMENT size: (25,27) from (13,14)
# Training grid AUGMENT size: (18,43) from (14,23)
# Training grid AUGMENT size: (21,24) from (13,14)
# Training grid AUGMENT size: (18,50) from (14,23)
# Training grid AUGMENT size: (18,26) from (13,14)
# Training grid AUGMENT size: (22,31) from (14,23)
# Training grid AUGMENT size: (21,37) from (14,23)
# Training grid AUGMENT size: (26,31) from (13,14)
# Training grid AUGMENT size: (14,28) from (14,23)
# Training grid AUGMENT size: (40,27) from (13,14)
# Training grid AUGMENT size: (27,28) from (14,23)
# Training grid AUGMENT size: (16,17) from (13,14)
# Training grid AUGMENT size: (27,37) from (13,14)
# Training grid AUGMENT size: (16,57) from (14,23)
# Training grid AUGMENT size: (30,16) from (13,14)
# Training grid AUGMENT size: (43,47) from (14,23)
# Training grid AUGMENT size: (41,60) from (14,23)
# Training grid AUGMENT size: (16,21) from (13,14)
# Training grid AUGMENT size: (35,45) from (14,23)
# Training grid AUGMENT size: (56,17) from (13,14)
# Training grid AUGMENT size: (46,18) from (13,14)
# Training grid AUGMENT size: (34,33) from (14,23)
# Training grid AUGMENT size: (16,21) from (13,14)
# Training grid AUGMENT size: (33,45) from (14,23)
# Training grid AUGMENT size: (41,37) from (13,14)
# Training grid AUGMENT size: (30,48) from (14,23)
# Training grid AUGMENT size: (43,23) from (14,23)
# Training grid AUGMENT size: (39,22) from (13,14)
# Training grid AUGMENT size: (22,29) from (13,14)
# Training grid AUGMENT size: (19,50) from (14,23)
# Training grid AUGMENT size: (23,36) from (14,23)
# Training grid AUGMENT size: (43,36) from (13,14)
# Training grid AUGMENT size: (21,24) from (14,23)
# Training grid AUGMENT size: (13,35) from (13,14)
# Training grid AUGMENT size: (29,28) from (14,23)
# Training grid AUGMENT size: (17,16) from (13,14)
# Training grid AUGMENT size: (18,28) from (14,23)
# Training grid AUGMENT size: (22,42) from (13,14)
# Training grid AUGMENT size: (32,46) from (14,23)
# Training grid AUGMENT size: (25,35) from (13,14)
# Training grid AUGMENT size: (27,28) from (13,14)
# Training grid AUGMENT size: (28,35) from (14,23)
# Training grid AUGMENT size: (18,31) from (14,23)
# Training grid AUGMENT size: (48,19) from (13,14)
# Training grid AUGMENT size: (13,20) from (13,14)
# Training grid AUGMENT size: (16,50) from (14,23)
# Training grid AUGMENT size: (31,24) from (14,23)
# Training grid AUGMENT size: (33,21) from (13,14)
# Training grid AUGMENT size: (23,37) from (14,23)
# Training grid AUGMENT size: (27,18) from (13,14)
# Training grid AUGMENT size: (21,23) from (13,14)
# Training grid AUGMENT size: (33,32) from (14,23)
# Training grid AUGMENT size: (20,39) from (14,23)
# Training grid AUGMENT size: (19,21) from (13,14)
# Training grid AUGMENT size: (26,60) from (14,23)
# Training grid AUGMENT size: (36,36) from (13,14)
# Training grid AUGMENT size: (23,34) from (14,23)
# Training grid AUGMENT size: (39,24) from (13,14)
# Training grid AUGMENT size: (15,34) from (13,14)
# Training grid AUGMENT size: (30,36) from (14,23)
# Training grid AUGMENT size: (33,35) from (14,23)
# Training grid AUGMENT size: (21,29) from (13,14)
# Training grid AUGMENT size: (18,27) from (13,14)
# Training grid AUGMENT size: (17,47) from (14,23)
# Training grid AUGMENT size: (17,34) from (13,14)
# Training grid AUGMENT size: (23,24) from (14,23)
# WARNING:tensorflow:From /content/CutieMLproject/model_cutie2_aspp.py:11: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Tensor("data_grid:0", shape=(?, ?, ?, 1), dtype=int32)
# WARNING:tensorflow:From /content/CutieMLproject/model_framework.py:42: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /content/CutieMLproject/model_framework.py:433: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /content/CutieMLproject/model_framework.py:49: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Tensor("data_image:0", shape=(?, ?, ?, 3), dtype=float32)
# WARNING:tensorflow:From /content/CutieMLproject/model_framework.py:415: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Tensor("image_encoder1_8/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 32), dtype=float32)
# Tensor("image_encoder1_8/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 32), dtype=float32)
# Tensor("image_encoder1_8/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 32), dtype=float32)
# Tensor("image_encoder1_8/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 32), dtype=float32)
# WARNING:tensorflow:From /content/CutieMLproject/model_framework.py:312: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# Tensor("image_aspp_1/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 32), dtype=float32)
# Tensor("image_aspp_2/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 32), dtype=float32)
# Tensor("image_aspp_3/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 32), dtype=float32)
# Tensor("ResizeNearestNeighbor:0", shape=(?, ?, ?, 32), dtype=float32)
# Tensor("image_encoder1_1/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 32), dtype=float32)
# Tensor("image_aspp_1x1/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 32), dtype=float32)
# Tensor("image_featuremap/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 32), dtype=float32)
# Tensor("ps_1d_indices:0", shape=(?, ?), dtype=int32)
# Tensor("data_grid:0", shape=(?, ?, ?, 1), dtype=int32)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:180: batch_gather (from tensorflow.python.ops.array_ops) is deprecated and will be removed after 2017-10-25.
# Instructions for updating:
# `tf.batch_gather` is deprecated, please use `tf.gather` with `batch_dims` instead.
# Tensor("Reshape_2:0", shape=(?, ?, ?, 32), dtype=float32)
# Tensor("embedding/Reshape_1:0", shape=(?, ?, ?, 128), dtype=float32)
# Tensor("feature_fuser/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 256), dtype=float32)
# Tensor("encoder1_8/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 256), dtype=float32)
# Tensor("encoder1_8/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 256), dtype=float32)
# Tensor("encoder1_8/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 256), dtype=float32)
# Tensor("encoder1_8/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 256), dtype=float32)
# Tensor("aspp_1/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 256), dtype=float32)
# Tensor("aspp_2/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 256), dtype=float32)
# Tensor("aspp_3/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 256), dtype=float32)
# Tensor("ResizeNearestNeighbor_1:0", shape=(?, ?, ?, 256), dtype=float32)
# Tensor("encoder1_1/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 256), dtype=float32)
# Tensor("aspp_1x1/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 256), dtype=float32)
# Tensor("decoder1_1/InstanceNorm/instancenorm/add_1:0", shape=(?, ?, ?, 64), dtype=float32)
# WARNING:tensorflow:From /content/CutieMLproject/model_cutie2.py:126: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/CutieMLproject/model_cutie2.py:138: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /content/CutieMLproject/model_cutie2.py:138: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/CutieMLproject/model_cutie2.py:141: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /content/CutieMLproject/main_train_json.py:162: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /content/CutieMLproject/main_train_json.py:171: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# CUTIE2_dilate :  14.269448 M parameters
#
# WARNING:tensorflow:From /content/CutieMLproject/main_train_json.py:189: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From /content/CutieMLproject/main_train_json.py:191: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# 2022-01-09 11:57:39.270540: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-01-09 11:57:39.273901: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2022-01-09 11:57:39.274173: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x560488bf4fc0 executing computations on platform Host. Devices:
# 2022-01-09 11:57:39.274211: I tensorflow/compiler/xla/service/service.cc:175]   StreamExecutor device (0): <undefined>, <undefined>
# 2022-01-09 11:57:39.853411: W tensorflow/compiler/jit/mark_for_compilation_pass.cc:1412] (One-time warning): Not using XLA:CPU for cluster because envvar TF_XLA_FLAGS=--tf_xla_cpu_global_jit was not set.  If you want XLA:CPU, either set that envvar, or use experimental_jit_scope to enable XLA:CPU.  To confirm that XLA is active, pass --vmodule=xla_compilation_cache=1 (as a proper command-line flag, not via TF_XLA_FLAGS) or set the envvar XLA_FLAGS=--xla_hlo_profile.
#  Let's roll!
# Training grid AUGMENT size: (15,29) from (13,14)
# 	 >>time per step: 6.60s <<
# /content/CutieMLproject/main_train_json.py:277: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(data['label_mapids']),
#
# Iter: 0/1000, total loss: 7.3996, model loss: 7.1731, regularization loss: 0.2264
# LOSS CURVE: 0:7.400
# TRAINING ACC CURVE: 0:0.000
# TRAINING ACC (Recall/Acc): 0.000 / 0.000 (0.000) | highest 0.000 / 0.000 (0.000)
# /content/CutieMLproject/main_train_json.py:318: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(data['label_mapids']),
# VALIDATION ACC (STRICT) CURVE: 0:0.000
# VALIDATION ACC (SOFT) CURVE: 0:0.000
# TRAINING RECALL CURVE: 0:0.00
# VALIDATION RECALL CURVE: 0:0.10
# VALIDATION Statistic 0(0) (Recall/Acc): 0.105 / 0.000 (0.000) | highest 0.105 / 0.000 (0.000)
#
# /content/CutieMLproject/main_train_json.py:381: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array(data['label_mapids']),
#
#  TEST ACC (Recall/Acc): 0.624 / 0.000 (0.571) | highest 0.624 / 0.000 (0.571)
#
# TEST ACC (STRICT) CURVE: 0:0.000
# TEST ACC (SOFT) CURVE: 0:0.571
# TEST RECALL CURVE: 0:0.62
# Training grid AUGMENT size: (35,61) from (14,23)
# Training grid AUGMENT size: (31,23) from (14,23)
# Training grid AUGMENT size: (29,28) from (13,14)
# Training grid AUGMENT size: (15,22) from (13,14)
# Training grid AUGMENT size: (25,39) from (14,23)
# Training grid AUGMENT size: (20,40) from (13,14)
# Training grid AUGMENT size: (30,26) from (14,23)
# Training grid AUGMENT size: (29,22) from (13,14)
# Training grid AUGMENT size: (29,30) from (14,23)
# Training grid AUGMENT size: (33,48) from (14,23)

# %%
pip install tensorflow==1.14.0.
# Out:
# Collecting tensorflow==1.14.0.
#   Downloading tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3 MB)
#      |████████████████████████████████| 109.3 MB 52 kB/s
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488 kB)
#      |████████████████████████████████| 488 kB 44.5 MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (1.13.3)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (0.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (0.37.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (0.2.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (1.15.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (0.8.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (1.19.5)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.3 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (1.42.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (0.4.0)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (1.14.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14.0.) (3.17.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14.0.) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0.) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0.) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0.) (57.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0.) (4.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0.) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0.) (3.10.0.2)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow==1.14.0.) (1.5.2)
# Installing collected packages: tensorflow-estimator, keras-applications, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.7.0
#     Uninstalling tensorflow-2.7.0:
#       Successfully uninstalled tensorflow-2.7.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.6 requires tensorflow>=2.0.0, but you have tensorflow 1.14.0 which is incompatible.
# Successfully installed keras-applications-1.0.8 tensorflow-1.14.0 tensorflow-estimator-1.14.0

# %%
# !python3 /content/CutieMLproject/main_build_dict.py
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
#
#
# DATASET: 223 vocabularies, 8 target classes
# DATASET: 2 for training, 1 for validation
# DATASET: 2 for test from /content/CutieMLproject/test
#
# Training statistic:  [(23, 1), (14, 2), (13, 1)]
# 	 num:  2
# 	 rows statistic:  [(14, 1), (13, 1)]
# 	 cols statistic:  [(23, 1), (14, 1)]
#
# Validation statistic:  [(30, 1), (21, 1)]
# 	 num:  1
# 	 rows statistic:  [(21, 1)]
# 	 cols statistic:  [(30, 1)]
#
# Test statistic:  [(33, 1), (22, 1), (20, 1), (14, 1)]
# 	 num:  2
# 	 rows statistic:  [(20, 1), (14, 1)]
# 	 cols statistic:  [(33, 1), (22, 1)]
#
# DATASHAPE: data set with maximum grid table of (14,23), updated.

# %%
# !python3 /content/CutieMLproject/main_data_tokenizer.py
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Tokenization succeed

# %%
# !python3 /content/CutieMLproject/tokenization.py
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
